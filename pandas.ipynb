# %%
 import pandas as pd

# %%
df = pd.DataFrame([11,22,33])
df
# Out:
#     0
# 0  11
# 1  22
# 2  33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Creating DataFrame

# %%
data = {
    'Name': ['NAINIKA', 'GANESH', 'HARRY', 'DAL-MI'],
    'Age': [20, 100, 24, 32],
    'Salary': [1000, 2000 , 3000 , 4000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Salary
# 0  NAINIKA   20    1000
# 1   GANESH  100    2000
# 2    HARRY   24    3000
# 3   DAL-MI   32    4000

# %% [markdown]
# DataFrame Attributes

# %%
df
# Out:
#       Name  Age  Salary
# 0  NAINIKA   20    1000
# 1   GANESH  100    2000
# 2    HARRY   24    3000
# 3   DAL-MI   32    4000

# %%
df.size
# Out:
# 12

# %%
df.shape
# Out:
# (4, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Salary': 'Monthly_Salary'}, inplace= True)

# %%
df.empty
# Out:
# False

# %% [markdown]
# Inspection of DataFrame

# %%
df
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %%
df.head(2)
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000

# %%
df.tail(2)
# Out:
#      Name  Age  Monthly_Salary
# 2   HARRY   24            3000
# 3  DAL-MI   32            4000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#               Age  Monthly_Salary
# count    4.000000        4.000000
# mean    44.000000     2500.000000
# std     37.665192     1290.994449
# min     20.000000     1000.000000
# 25%     23.000000     1750.000000
# 50%     28.000000     2500.000000
# 75%     49.000000     3250.000000
# max    100.000000     4000.000000

# %% [markdown]
# Saved and Load Data from csv

# %%
df.to_csv('Test_data.csv', index=False)
load_df = pd.read_csv('Test_data.csv')
load_df
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %% [markdown]
# Column Selection

# %%
df
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %%
df[['Name']]
# Out:
#       Name
# 0  NAINIKA
# 1   GANESH
# 2    HARRY
# 3   DAL-MI

# %%
df[['Name', 'Monthly_Salary']]
# Out:
#       Name  Monthly_Salary
# 0  NAINIKA            1000
# 1   GANESH            2000
# 2    HARRY            3000
# 3   DAL-MI            4000

# %% [markdown]
# Row Selection

# %%
df
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %%
df.loc[df.Name=='NAINIKA']
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000

# %%
df.loc[0:2]
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000

# %%
df.iloc[1]
# Out:
# Name              GANESH
# Age                  100
# Monthly_Salary      2000
# Name: 1, dtype: object

# %%
df.iloc[0:2]
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000

# %% [markdown]
# Filter DataFrame

# %%
df
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %%
df[df['Age'] > 20]
# Out:
#      Name  Age  Monthly_Salary
# 1  GANESH  100            2000
# 2   HARRY   24            3000
# 3  DAL-MI   32            4000

# %%
df[(df['Age'] >= 18) & (df['Monthly_Salary'] >= 3000)]
# Out:
#      Name  Age  Monthly_Salary
# 2   HARRY   24            3000
# 3  DAL-MI   32            4000

# %%
df.where(df['Age'] >= 18)
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %%
df.where(df['Age'] >= 18, other = 'Not Eligible')
# Out:
#       Name  Age  Monthly_Salary
# 0  NAINIKA   20            1000
# 1   GANESH  100            2000
# 2    HARRY   24            3000
# 3   DAL-MI   32            4000

# %% [markdown]
# Add Column

# %%
df['Team'] = ['CEO', 'CTO', 'HR', 'DS']
df
# Out:
#       Name  Age  Monthly_Salary Team
# 0  NAINIKA   20            1000  CEO
# 1   GANESH  100            2000  CTO
# 2    HARRY   24            3000   HR
# 3   DAL-MI   32            4000   DS

# %%
df['Bonus'] = df['Monthly_Salary'] * 0.2
df
# Out:
#       Name  Age  Monthly_Salary Team  Bonus
# 0  NAINIKA   20            1000  CEO  200.0
# 1   GANESH  100            2000  CTO  400.0
# 2    HARRY   24            3000   HR  600.0
# 3   DAL-MI   32            4000   DS  800.0

# %% [markdown]
# Add Row

# %%
df.loc[len(df)] = ['KRISHNA', 21, 2100, 'AIML', 200]
df
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus
# 0  NAINIKA   20            1000   CEO  200.0
# 1   GANESH  100            2000   CTO  400.0
# 2    HARRY   24            3000    HR  600.0
# 3   DAL-MI   32            4000    DS  800.0
# 4  KRISHNA   21            2100  AIML  200.0

# %% [markdown]
# Delete Value

# %%
df.drop(df[df.Name == 'NAINIKA'].index)
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus
# 1   GANESH  100            2000   CTO  400.0
# 2    HARRY   24            3000    HR  600.0
# 3   DAL-MI   32            4000    DS  800.0
# 4  KRISHNA   21            2100  AIML  200.0

# %%
df.drop('Bonus', axis=1)
# Out:
#       Name  Age  Monthly_Salary  Team
# 0  NAINIKA   20            1000   CEO
# 1   GANESH  100            2000   CTO
# 2    HARRY   24            3000    HR
# 3   DAL-MI   32            4000    DS
# 4  KRISHNA   21            2100  AIML

# %% [markdown]
# Sort Value

# %%
df.sort_values('Monthly_Salary')
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus
# 0  NAINIKA   20            1000   CEO  200.0
# 1   GANESH  100            2000   CTO  400.0
# 4  KRISHNA   21            2100  AIML  200.0
# 2    HARRY   24            3000    HR  600.0
# 3   DAL-MI   32            4000    DS  800.0

# %% [markdown]
# Working with Data Value

# %%
df
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus
# 0  NAINIKA   20            1000   CEO  200.0
# 1   GANESH  100            2000   CTO  400.0
# 2    HARRY   24            3000    HR  600.0
# 3   DAL-MI   32            4000    DS  800.0
# 4  KRISHNA   21            2100  AIML  200.0

# %%
df['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03', '2024-04-07']
df
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus         DOJ
# 0  NAINIKA   20            1000   CEO  200.0  2024-01-01
# 1   GANESH  100            2000   CTO  400.0  2024-01-15
# 2    HARRY   24            3000    HR  600.0  2024-03-28
# 3   DAL-MI   32            4000    DS  800.0  2024-03-03
# 4  KRISHNA   21            2100  AIML  200.0  2024-04-07

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0      Monday
# 1      Monday
# 2    Thursday
# 3      Sunday
# 4      Sunday
# Name: DOJ, dtype: object

# %%
df['Month'] = df['DOJ'].dt.month
df
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus        DOJ  Month
# 0  NAINIKA   20            1000   CEO  200.0 2024-01-01      1
# 1   GANESH  100            2000   CTO  400.0 2024-01-15      1
# 2    HARRY   24            3000    HR  600.0 2024-03-28      3
# 3   DAL-MI   32            4000    DS  800.0 2024-03-03      3
# 4  KRISHNA   21            2100  AIML  200.0 2024-04-07      4

# %%
df['DOJ'] + pd.Timedelta(days=90)
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# 3   2024-06-01
# 4   2024-07-06
# Name: DOJ, dtype: datetime64[ns]

# %% [markdown]
# Handling with Null Values

# %%
df
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus        DOJ  Month
# 0  NAINIKA   20            1000   CEO  200.0 2024-01-01      1
# 1   GANESH  100            2000   CTO  400.0 2024-01-15      1
# 2    HARRY   24            3000    HR  600.0 2024-03-28      3
# 3   DAL-MI   32            4000    DS  800.0 2024-03-03      3
# 4  KRISHNA   21            2100  AIML  200.0 2024-04-07      4

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team  Bonus    DOJ  Month
# 0  False  False           False  False  False  False  False
# 1  False  False           False  False  False  False  False
# 2  False  False           False  False  False  False  False
# 3  False  False           False  False  False  False  False
# 4  False  False           False  False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name=='NAINIKA', 'Monthly_Salary'] = np.nan
df
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus        DOJ  Month
# 0  NAINIKA   20             NaN   CEO  200.0 2024-01-01      1
# 1   GANESH  100          2000.0   CTO  400.0 2024-01-15      1
# 2    HARRY   24          3000.0    HR  600.0 2024-03-28      3
# 3   DAL-MI   32          4000.0    DS  800.0 2024-03-03      3
# 4  KRISHNA   21          2100.0  AIML  200.0 2024-04-07      4

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team  Bonus    DOJ  Month
# 0  False  False            True  False  False  False  False
# 1  False  False           False  False  False  False  False
# 2  False  False           False  False  False  False  False
# 3  False  False           False  False  False  False  False
# 4  False  False           False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# Name              0
# Age               0
# Monthly_Salary    1
# Team              0
# Bonus             0
# DOJ               0
# Month             0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       Name  Age  Monthly_Salary  Team  Bonus        DOJ  Month
# 0  NAINIKA   20             0.0   CEO  200.0 2024-01-01      1
# 1   GANESH  100          2000.0   CTO  400.0 2024-01-15      1
# 2    HARRY   24          3000.0    HR  600.0 2024-03-28      3
# 3   DAL-MI   32          4000.0    DS  800.0 2024-03-03      3
# 4  KRISHNA   21          2100.0  AIML  200.0 2024-04-07      4

# %% [markdown]
# Aggregation

# %%
df['Month'].value_counts()
# Out:
# Month
# 1    2
# 3    2
# 4    1
# Name: count, dtype: int64

# %%
df[df['Month']==1].value_counts()
# Out:
# Name    Age  Monthly_Salary  Team  Bonus  DOJ         Month
# GANESH  100  2000.0          CTO   400.0  2024-01-15  1        1
# Name: count, dtype: int64

# %% [markdown]
# Group by

# %%
df.groupby('Month')['Monthly_Salary'].sum()
# Out:
# Month
# 1    2000.0
# 3    7000.0
# 4    2100.0
# Name: Monthly_Salary, dtype: float64

# %%
df.groupby('Month').agg({'Monthly_Salary': 'mean', 'Name': 'count'})
# Out:
#        Monthly_Salary  Name
# Month
# 1              2000.0     2
# 3              3500.0     2
# 4              2100.0     1

# %% [markdown]
# Concatenate Dataframe

# %%
df1 = pd.DataFrame({'ID':[1,2,3],'Name':['A','B','C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({'ID':[1,2,2,4],'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
pd.concat([df1, df2], axis=0)
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %% [markdown]
# Merge DataFrame

# %%
pd.merge(df1, df2, how='inner', on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1, df2, how='inner', left_on='ID', right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
